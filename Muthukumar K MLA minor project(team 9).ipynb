# %%
import pandas as pd

# %%
import  numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv(r"D:\dataset for ML\Housing.csv")

# %%
data
# Out:
#         price  area  parking
# 0    13300000  7420        2
# 1    12250000  8960        3
# 2    12250000  9960        2
# 3    12215000  7500        3
# 4    11410000  7420        2
# ..        ...   ...      ...
# 540   1820000  3000        2
# 541   1767150  2400        0
# 542   1750000  3620        0
# 543   1750000  2910        0
# 544   1750000  3850        0
#
# [545 rows x 3 columns]

# %%
x=data.drop('price',axis=1)

# %%
x
# Out:
#      area  parking
# 0    7420        2
# 1    8960        3
# 2    9960        2
# 3    7500        3
# 4    7420        2
# ..    ...      ...
# 540  3000        2
# 541  2400        0
# 542  3620        0
# 543  2910        0
# 544  3850        0
#
# [545 rows x 2 columns]

# %%
y=data['price']
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
x_test,x_train,y_test,y_train=train_test_split(x,y,test_size=0.2)

# %%
regressor=LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
df=regressor.predict(x_test)

# %%
dd=pd.DataFrame(df)

# %%
dd
# Out:
#                 0
# 0    4.806404e+06
# 1    5.865769e+06
# 2    8.468590e+06
# 3    5.677134e+06
# 4    3.612117e+06
# ..            ...
# 431  4.152493e+06
# 432  3.804190e+06
# 433  7.213715e+06
# 434  5.161503e+06
# 435  4.703966e+06
#
# [436 rows x 1 columns]

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error

# %%
mae=mean_absolute_error(y_test,df)

# %%
mse=mean_squared_error(y_test,df)

# %%
sk=np.sqrt(mse)

# %%
print("Mean_absolute_error: ",mae)
print("Mean_squared_error: ",mse)
print("Squareroot of MSE: ",sk)
# Out:
# Mean_absolute_error:  1152230.647203217
# Mean_squared_error:  2353868799713.552
# Squareroot of MSE:  1534232.3160830473

# %%
plt.figure(figsize=(12,6))
plt.plot(x_test,df)
plt.title("House Pricing")
plt.xlabel("x_test")
plt.ylabel("Predicted")
plt.show()

# %%
data['area'].value_counts().sort_index().plot(kind='pie',title='Counts of Label ',figsize=(10,5))
# Out:
# <Axes: title={'center': 'Counts of Label '}, ylabel='count'>

# %%
data['price'].value_counts().sort_index().plot(kind='bar',title='Counts of Label ',figsize=(10,5))
# Out:
# <Axes: title={'center': 'Counts of Label '}, xlabel='price'>

# %%
data['price'].value_counts().sort_index().plot(kind='pie',title='Counts of Label ',figsize=(10,5))
# Out:
# <Axes: title={'center': 'Counts of Label '}, ylabel='count'>

# %%
data['price'].value_counts().sort_index().plot(kind='line',title='Counts of Label ',figsize=(10,5))
# Out:
# <Axes: title={'center': 'Counts of Label '}, xlabel='price'>
